# %%
import requests

#http://api.weatherapi.com/v1/current.json?key=d91892161f2545d684b214649210512&q=London
API_Key = 'd91892161f2545d684b214649210512'
API_URL = 'http://api.weatherapi.com/v1'
API_method = '/current.json?'
API_city='q= ' + input('City: ')

response=requests.get(API_URL+API_method+'key='+API_Key+'&'+API_city)
print(response.content)

#http://api.weatherapi.com/v1/forecast.json?key=d91892161f2545d684b214649210512&q=London&days
API_method_2 = '/forecast.json?'

response=requests.get(API_URL+API_method_2+'key='+API_Key+'&'+API_city)
print(response.content)
# Out:
# City: Moscow
# b'{"location":{"name":"Moscow","region":"Moscow City","country":"Russia","lat":55.75,"lon":37.62,"tz_id":"Europe/Moscow","localtime_epoch":1638742511,"localtime":"2021-12-06 1:15"},"current":{"last_updated_epoch":1638738000,"last_updated":"2021-12-06 00:00","temp_c":-3.0,"temp_f":26.6,"is_day":0,"condition":{"text":"Overcast","icon":"//cdn.weatherapi.com/weather/64x64/night/122.png","code":1009},"wind_mph":6.9,"wind_kph":11.2,"wind_degree":180,"wind_dir":"S","pressure_mb":1016.0,"pressure_in":30.0,"precip_mm":0.0,"precip_in":0.0,"humidity":93,"cloud":100,"feelslike_c":-4.6,"feelslike_f":23.7,"vis_km":6.0,"vis_miles":3.0,"uv":1.0,"gust_mph":5.1,"gust_kph":8.3}}'
# ...
