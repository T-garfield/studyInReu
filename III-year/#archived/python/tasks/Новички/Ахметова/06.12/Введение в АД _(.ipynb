# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Nedvig.csv', delimiter=';', decimal=',', encoding="cp1251")
print(data)
# Out:
#     Номер  Район  Число комнат   Тип дома  Общая  Жилая  Кухня  Цена, тыс. руб.
# 0       1    ЮМР             1    блочный     40     20     10           1596.0
# 1       2    ЮМР             2    блочный     60     32     10           1876.0
# 2       3    ЮМР             2    блочный     77     40     16           3500.0
# 3       4    ЮМР             3    блочный     66     42      9           2074.8
# 4       5    ЮМР             3    блочный     70     44     10           2156.0
# ..    ...    ...           ...        ...    ...    ...    ...              ...
# 64     65  Центр             4  кирпичный    102     70      8           3780.0
# 65     66  Центр             4    блочный     82     52     10           3360.0
# 66     67  Центр             4    блочный    162     86     13           5880.0
# 67     68  Центр             4  кирпичный    115     85     10           3360.0
# 68     69  Центр             4  кирпичный     93     52     11           2324.0
#
# ...

# %%
print('Минимальное значение: ', int(data['Цена, тыс. руб.'].min()))
# Out:
# Минимальное значение:  1344

# %%
print('Минимальное значение: ', int(data['Цена, тыс. руб.'].max()))
# Out:
# Максимальное значение:  5880

# %%
print('Среднее значение: ', int(data['Цена, тыс. руб.'].mean()))
# Out:
# Среднее значение:  2625

# %%
print('Модальное значение: ', int(data['Цена, тыс. руб.'].mode()))
# Out:
# Модальное значение:  2380

# %%
print('Медианное значение: ', int(data['Цена, тыс. руб.'].median()))
# Out:
# Медианное значение:  2489

# %%
flat1 = data.loc[data['Число комнат'] == 1]
print(flat1)
print('Минимальное значение: ', int(flat1['Цена, тыс. руб.'].min()))
print('Минимальное значение: ', int(flat1['Цена, тыс. руб.'].max()))
print('Среднее значение: ', int(flat1['Цена, тыс. руб.'].mean()))
print('Модальное значение: ', str(flat1['Цена, тыс. руб.'].mode()))
print('Медианное значение: ', int(flat1['Цена, тыс. руб.'].median()))
# Out:
#     Номер  Район  Число комнат Тип дома  Общая  Жилая  Кухня  Цена, тыс. руб.
# 0       1    ЮМР             1  блочный     40     20     10           1596.0
# 39     40  Центр             1  блочный     37     17      8           1344.0
# Минимальное значение:  1344
# Минимальное значение:  1596
# Среднее значение:  1470
# Модальное значение:  0    1344.0
# 1    1596.0
# dtype: float64
# Медианное значение:  1470

# %%
flat2 = data.loc[data['Число комнат'] == 2]
print(flat2)
print('Минимальное значение: ', int(flat2['Цена, тыс. руб.'].min()))
print('Минимальное значение: ', int(flat2['Цена, тыс. руб.'].max()))
print('Среднее значение: ', int(flat2['Цена, тыс. руб.'].mean()))
print('Модальное значение: ', str(flat2['Цена, тыс. руб.'].mode()))
print('Медианное значение: ', int(flat2['Цена, тыс. руб.'].median()))
# Out:
#     Номер  Район  Число комнат   Тип дома  Общая  Жилая  Кухня  Цена, тыс. руб.
# 1       2    ЮМР             2    блочный     60     32     10           1876.0
# 2       3    ЮМР             2    блочный     77     40     16           3500.0
# 40     41  Центр             2  кирпичный     35     23      5           2436.0
# 41     42  Центр             2    блочный     36     24      4           1960.0
# 42     43  Центр             2    блочный     45     26      8           2100.0
# 43     44  Центр             2    блочный     38     33      5           1540.0
# 44     45    СМР             2  кирпичный     45     21     12           2240.0
# 45     46    СМР             2    блочный     80     41     15           1764.0
# 46     47    СМР             2    блочный     91     60     12           3007.2
# 47     48    СМР             2    блочный     50     30      7           1484.0
# 48     49  Центр             2    блочный     65     45     16           2380.0
# ...

# %%
flat4 = data.loc[data['Число комнат'] == 4]
print(flat4)
print('Минимальное значение: ', int(flat4['Цена, тыс. руб.'].min()))
print('Минимальное значение: ', int(flat4['Цена, тыс. руб.'].max()))
print('Среднее значение: ', int(flat4['Цена, тыс. руб.'].mean()))
print('Модальное значение: ', str(flat4['Цена, тыс. руб.'].mode()))
print('Медианное значение: ', int(flat4['Цена, тыс. руб.'].median()))
# Out:
#     Номер  Район  Число комнат   Тип дома  Общая  Жилая  Кухня  Цена, тыс. руб.
# 21     22    СМР             4    блочный    123     70     26          3827.60
# 22     23    СМР             4    блочный     80     52      9          2520.00
# 23     24    СМР             4  кирпичный     88     54      9          2520.00
# 24     25    СМР             4    блочный     87     56     10          2380.00
# 25     26    СМР             4    блочный     78     56     10          2240.00
# 26     27    СМР             4    блочный    117     63     15          3304.00
# 27     28    СМР             4    блочный     91     56     10          3424.40
# 28     29    СМР             4  кирпичный    100     73      8          2702.00
# 29     30    ЮМР             4    блочный     95     61     15          2800.00
# 30     31    ЮМР             4    блочный    100     73      8          2688.00
# 31     32    ЮМР             4  кирпичный    100     73      8          2702.00
# ...

# %%
print(data.sort_values(by=['Цена, тыс. руб.'], ascending=False))
# Out:
#     Номер  Район  Число комнат   Тип дома  Общая  Жилая  Кухня  Цена, тыс. руб.
# 66     67  Центр             4    блочный    162     86     13           5880.0
# 58     59    ГМР             3    блочный     66     49      6           5600.0
# 38     39    ЮМР             5  кирпичный    130     90     15           5180.0
# 37     38    ЮМР             5    блочный    150    100     20           4354.0
# 21     22    СМР             4    блочный    123     70     26           3827.6
# ..    ...    ...           ...        ...    ...    ...    ...              ...
# 51     52  Центр             3    блочный     52     36      7           1540.0
# 61     62  Центр             3    блочный     54     38      6           1506.4
# 47     48    СМР             2    блочный     50     30      7           1484.0
# 56     57    ГМР             3    блочный     51     29      8           1348.2
# 39     40  Центр             1    блочный     37     17      8           1344.0
#
# ...
