# %%
#Задание 1
print();
favour_word = "Лейкопластырь";
print(favour_word);
print();
print();

#Задание 2
print();
first_name = "Родриго";
last_name = "Вильянуэва";
new_account = last_name[:5];
temp_password = last_name[3:7];
print(new_account);
print(temp_password);
print();
print();

#Задание 3
print();
def account_generator(first_name, last_name):
  return first_name[:3] + last_name[:3]
new_account = account_generator(first_name, last_name);
print(new_account);
print();
print();

#Задание 4
print();
def password_generator(first_name, last_name):
  first_name_length = len(first_name)
  last_name_length = len(last_name)
  return first_name[first_name_length-3:] + last_name[last_name_length-3:]
temp_password = password_generator(first_name, last_name);
print(temp_password);
print();
print();

#Задание 5
print();
company_motto= "Мечты сбываются";
second_to_last = company_motto[-2];
print(second_to_last);
final_word = company_motto[-4:];
print(final_word);
print();
print();

#Задание 6
print();
def show_name(first_name, last_name):
  print(first_name + " " + last_name)
first_name = "Pob";
last_name = "Daily";
show_name(first_name, last_name);
fixed_first_name = "R" + first_name[1:];
show_name(fixed_first_name, last_name);
print();
print();

#Задание 7
print();
password = "theycallme\"crazy\"91";
print(password);
print();
print();

#Задание 8
print();
def get_length(string):
  return len(string)
my_string = "О закрой свои бледные ноги."
print(str(get_length(my_string)));
print();
print();

#Задание 9
print();
def letter_check(word, letter):
  counter = 0
  for i in word:
    if i == letter:
      counter = counter + 1
      break
  if counter == 0:
    print(False)
  else:
    print(True)
letter_check("alphabet", "a");
letter_check("table", "o");
print();
print();

#Задание 10
print();
def contains(big_string, little_string):
  return little_string in big_string
print(contains("watermelon", "melon"));
print(contains("watermelon", "apple"));
def common_letters(string1, string2):
  letters = []
  for i in string1:
    if (i in string2) and (i not in letters):
      letters.append(i)
  if letters == []:
    print("Нет совпадений")
  else:
    print(letters);
common_letters("banana", "cream");
common_letters("крокодил", "керосин");
common_letters("француз", "мощь");
print();
print();

#Задание 11
print();
def username_generator(first_name, last_name):
  return first_name[:3] + last_name[:4]
print(username_generator("Abe", "Simpson"));
def password_generator(username):
  password = ""
  for i in range(len(username)):
    password = password + username[i-1]
  return password
print(password_generator(username_generator("Abe", "Simpson")));
