# %%
#Задание 1
print();
sam_height = ["Sam", 67];
print();
print();

#Задание 2
print();
heights = [['Jenny', 61], ['Alexus', 70], ['Sam', 67], ['Grace', 64], ['Vick', 68]];
ages = [['Aaron', 15], ['Dhruty', 16]];
print();
print();

#Задание 3
print();
names = ['Ben', 'Holly', 'Ann'];
dogs_names = ['Sharik', 'Gab', 'Beethoven'];
names_and_dogs_names = zip(names, dogs_names);
list_of_names_and_dogs_names = list(names_and_dogs_names)
print(list_of_names_and_dogs_names);
print();
print();

#Задание 4
print();
orders = ['маргаритки', 'барвинок'];
orders.append('тюльпаны');
orders.append('розы');
print(orders);
print();
print();

#Задание 5
print();
orders = ['маргаритка', 'лютик', 'львиный зев', 'гардения', 'лилия'];
orders = orders + ['сирень', 'ирис'];
broken_prices = [5, 3, 4, 5, 4] + [4];
print();
print();

#Задание 6
print();
list1 = range(1, 9);
print(list(list1));
list2 = range(8);
print(list(list2));
print();
print();

#Задание 7
print();
list1 = range(5, 15, 3);
print(list(list1));
list2 = range(0, 40, 5);
print(list(list2));
print();
print();

#Задание 8
print();
first_names = ["Эйнсли", "Бен", "Чани", "Депак"];
print(first_names);
age = [];
age.append(42);
print(age);
all_ages = [32, 41, 29];
print(all_ages);
all_ages = all_ages + age;
print(all_ages);
name_and_age = zip(first_names, all_ages);
print(list(name_and_age));
ids = range(4);
print(list(ids));
