# %%
#Задание 1
print();
def check_5000(base, exp):
  num = base ** exp
  if num < 5000:
    return True
  else:
    return False
print(check_5000(2, 4));
print(check_5000(10,10));
print();
print();

#Задание 2
print();
def check_range(num, low, high):
  if (num > low) and (num < high):
    return True
  else:
    return False
print(check_range(10, 6, 16));
print(check_range(10, 12, 16));
print(check_range(10, 2, 6));
print();
print();

#Задание 3
print();
def check_name(your_name, my_name):
  if your_name == my_name:
    return True
  else:
    return False
print(check_name("Alexander", "Alexander"));
print(check_name("Alexander", "Sasha"));
print();
print();

#Задание 4
print();
def another_function(num):
  if (num > 10) and (num < 8):
    return True
  else:
    return False 
print(another_function(7));
print(another_function(12));
print();
print();

#Задание 5
print();
def rate_film(rating):
  if rating < 5:
    print("Избегать любой ценой!")
  elif rating < 9:
    print("Это было весело.")
  else:
    print("Отлично!")
rate_film(3);
rate_film(7);
rate_film(10);
print();
print();

#Задание 6
print();
def find_highest(num1, num2, num3):
  if (num1 > num2) and (num1 > num3):
    return num1
  elif (num2 > num1) and (num2 > num3):
    return num2
  elif (num3 > num1) and (num3 > num2):
    return num3
  else:
    return "Ничья!"
print(find_highest(3, 2, 1));
print(find_highest(4, 6, 5));
print(find_highest(7, 8, 9));
print(find_highest(10, 11, 11));
print();
print();

#Задание 7
print();
def tenth_power(base):
  return base ** 10
def square_root(base):
  return base ** 0.5
print(tenth_power(2));
print(square_root(tenth_power(2)));
print();
print();

#Задание 8
print();
def win_rate(wins, loses):
  games = wins + loses
  win_rate = wins / games
  return str(win_rate * 100) + " %"
print(win_rate(5, 5));
print(win_rate(25, 5));
print();
print();

#Задание 9
print();
def find_med(num1, num2):
  sum = num1 + num2
  return sum/2
print(find_med(4, 8));
print();
print();

#Задание 10
print();
def find_remainder(num1, num2):
  num1 = num1 / 2
  num2 = num2 / 2
  return num1 % num2
print(find_remainder(12, 8));
print();
print();

#Задание 11
print();
def what_the(num):
  print(num)
  print(num * 2)
  print(num * 3)
  return num * 3
what_the(3);
print();
what_the_3 = what_the(3);
print(what_the_3);
print();
print();

#Задание 11(2)
print();
def find_tea(total, percent):
  return total * percent / 100
print(find_tea(1000, 10));
print();
print();

#Задание 12
print("A")
print();
def function_a(x):
  if x <= -2:
    return 1 - ((x + 2) ** 2)
  elif (x > -2) and (x <= 2):
    return -1 * x / 2
  else:
    return ((x - 2) ** 2) + 1 
print(function_a(-3));
print(function_a(1));
print(function_a(4));
print();
print("Б");
print();
def function_1(x):
  return 1 - ((x + 2) ** 2)
def function_2(x):
  return -1 * x / 2
def function_3(x):
  return ((x - 2) ** 2) + 1 
def function_b(x):
  if x <= -2:
    return function_1(x)
  elif (x > -2) and (x <= 2):
    return function_2(x)
  else:
    return function_3(x)
print(function_b(-3));
print(function_b(1));
print(function_b(4));
print();
print();

#Задание 13
print();
def calc(num1, num2, operator):
  if operator == "+":
    return num1 + num2
  elif operator == "-":
    return num1 - num2
  elif operator == "*":
    return num1 * num2
  elif operator == ":":
    return num1/num2
  else:
    return "Неверный оператор :("
print(calc(80, 4, "+"));
print(calc(80, 4, "-"));
print(calc(80, 4, "*"));
print(calc(80, 4, ":"));
print(calc(80, 4, "ящерица"));
print();
print();

#Задание 14
print();
def stone_scissors_paper(first, second):
  if first == "stone":
    if second == "stone":
      return "Ничья"
    elif second == "scissors":
      return "Победил первый"
    elif second == "paper": 
      return "Победил второй"
    else:
      return "Что-то пошло не так"
  elif first == "scissors":
    if second == "scissors":
      return "Ничья"
    elif second == "paper":
      return "Победил первый"
    elif second == "stone": 
      return "Победил второй"
    else:
      return "Что-то пошло не так"
  elif first == "paper":
    if second == "paper":
      return "Ничья"
    elif second == "stone":
      return "Победил первый"
    elif second == "scissors": 
      return "Победил второй"
    else:
      return "Что-то пошло не так"
  else: 
    return "Что-то пошло не так"
print(stone_scissors_paper("stone", "paper"));
print(stone_scissors_paper("scissors", "paper"));
print(stone_scissors_paper("paper", "orange"))
# Out:
# True
# False
#
#
#
# True
# False
# False
#
#
#
# True
# False
#
#
#
# False
# False
#
#
#
# Избегать любой ценой!
# Это было весело.
# Отлично!
#
#
#
# 3
# 6
# 9
# Ничья!
#
#
#
# 1024
# 32.0
#
#
#
# 50.0 %
# 83.33333333333334 %
#
#
#
# 6.0
#
#
#
# 2.0
#
#
#
# 3
# 6
# 9
#
# 3
# 6
# 9
# 9
#
#
#
# 100.0
#
#
# A
#
# 0
# -0.5
# 5
#
# Б
#
# 0
# -0.5
# 5
#
#
#
# 84
# 76
# 320
# 20.0
# Неверный оператор :(
#
#
#
# Победил второй
# Победил первый
# Что-то пошло не так
